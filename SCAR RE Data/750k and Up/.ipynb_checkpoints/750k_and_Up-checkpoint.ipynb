# %%
import pandas as pd
import plotly.express as px
import os
from pathlib import Path
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Prep Mapbox API Credentials

# %%
# Set up API credentials
brevard_map_api = os.getenv("MAPBOX_API_KEY")

# Set the Mapbox API
px.set_mapbox_access_token(brevard_map_api)

# %% [markdown]
# ### Read in Data

# %%
brevard_df = pd.read_csv(
    Path(r"750k_and_up_bootcamp.csv")
)
brevard_df.head()
# Out:
#    Ag Value  Total Bathrooms  Bedrooms  Total Building Area  Lot Depth (ft)  \
# 0         0              NaN       NaN               4345.0             NaN
# 1         0              NaN       NaN               7609.0             NaN
# 2         0              3.0       5.0              10617.0             NaN
# 3         0              5.0       4.0               5729.0             NaN
# 4         0              NaN       NaN               9288.0             NaN
#
#    Effective Year Built  Total Exempt Value Fireplace Flag  Fireplace Count  \
# 0                2015.0               50000              f              NaN
# 1                2005.0               50000              t              2.0
# 2                2005.0               50000              t              1.0
# 3                2010.0               50000              t              1.0
# 4                2005.0               50000              t              3.0
#
#    Bathroom Fixtures  ...  Total Assessed Value Property Use Code  \
# 0                NaN  ...                633730                 1
# 1                NaN  ...                697960                 1
# 2                NaN  ...                622920                 1
# 3                NaN  ...                592150                 1
# 4                NaN  ...                829230                 1
#
#     Property Use Description Year Built            Grantor, Sale 1  \
# 0  SINGLE FAMILY RESIDENTIAL     2015.0  REDUS FLORIDA HOUSING LLC
# 1  SINGLE FAMILY RESIDENTIAL     1988.0       BLUMENTHAL GABRIEL H
# 2  SINGLE FAMILY RESIDENTIAL     1990.0           LEVINE RICHARD M
# 3  SINGLE FAMILY RESIDENTIAL     2001.0                        NaN
# 4  SINGLE FAMILY RESIDENTIAL     1991.0           WHITWORTH R LEON
#
#                 Grantor, Sale 2    Phone Number     Phone Contact  \
# 0       CERTIFIED BUILDING CORP  (321) 726-9116   Denise Nesbitt
# 1             GAGLIARDI JERRY F  (321) 269-6939  Patricia Barnes
# 2  INDIAN RIVER INVESTMENT CORP  (321) 268-3147   Richard Levine
# 3                           NaN  (321) 267-9352   Stephanie Welk
# 4                  MANZO ROSE A  n/a (DNC List)               NaN
#
#    In Opportunity Zone (Y/N)  Opportunity Zone Description
# 0                          N                           NaN
# 1                          N                           NaN
# 2                          N                           NaN
# 3                          N                           NaN
# 4                          N                           NaN
#
# [5 rows x 70 columns]

# %%
brevard_df.shape
# Out:
# (2091, 70)

# %%
print(list(brevard_df.columns))
# Out:
# ['Ag Value', 'Total Bathrooms', 'Bedrooms', 'Total Building Area', 'Lot Depth (ft)', 'Effective Year Built', 'Total Exempt Value', 'Fireplace Flag', 'Fireplace Count', 'Bathroom Fixtures', 'Lot Frontage (ft)', 'Garage Flag', 'Garage Size (sf)', 'Garage Type', 'Total Heated (Living) Area', 'Improvement 1 Code', 'Improvement 1 Description', 'Improvement 1 Units', 'Improvement 2 Code', 'Improvement 2 Description', 'Improvement 2 Units', 'Improvement 3 Code', 'Improvement 3 Description', 'Improvement 3 Units', 'Total Improved Value', 'Just Land Value', 'Just Value', 'Lot Size (acres)', 'Lot Size (sf)', 'Land Value', 'Legal Description', 'Owner Address', 'Owner City', 'Owner Name 1', 'Owner Name 2', 'Owner State', 'Owner Postal Code', 'Parcel ID', 'Pool Flag', 'Pool Size (sf)', 'Property Address', 'Property City', 'Property State', 'Property Zip Code', 'Sale 1 Book', 'Sale 1 Date', 'Sale 1 Document Type', 'Sale 1 Page', 'Sale 1 Price', 'Sale 1 Vacant/Improved', 'Sale 2 Book', 'Sale 2 Date', 'Sale 2 Document Type', 'Sale 2 Page', 'Sale 2 Price', 'Sale 2 Vacant/Improved', 'Subdivision Name', 'Taxable Value', 'Total Taxes', 'Tax Roll Year', 'Total Assessed Value', 'Property Use Code', 'Property Use Description', 'Year Built', 'Grantor, Sale 1', 'Grantor, Sale 2', 'Phone Number', 'Phone Contact', 'In Opportunity Zone (Y/N)', 'Opportunity Zone Description']

# %%
brevard_df.columns
# Out:
# Index(['Ag Value', 'Total Bathrooms', 'Bedrooms', 'Total Building Area',
#        'Lot Depth (ft)', 'Effective Year Built', 'Total Exempt Value',
#        'Fireplace Flag', 'Fireplace Count', 'Bathroom Fixtures',
#        'Lot Frontage (ft)', 'Garage Flag', 'Garage Size (sf)', 'Garage Type',
#        'Total Heated (Living) Area', 'Improvement 1 Code',
#        'Improvement 1 Description', 'Improvement 1 Units',
#        'Improvement 2 Code', 'Improvement 2 Description',
#        'Improvement 2 Units', 'Improvement 3 Code',
#        'Improvement 3 Description', 'Improvement 3 Units',
#        'Total Improved Value', 'Just Land Value', 'Just Value',
#        'Lot Size (acres)', 'Lot Size (sf)', 'Land Value', 'Legal Description',
#        'Owner Address', 'Owner City', 'Owner Name 1', 'Owner Name 2',
#        'Owner State', 'Owner Postal Code', 'Parcel ID', 'Pool Flag',
#        'Pool Size (sf)', 'Property Address', 'Property City', 'Property State',
#        'Property Zip Code', 'Sale 1 Book', 'Sale 1 Date',
#        'Sale 1 Document Type', 'Sale 1 Page', 'Sale 1 Price',
#        'Sale 1 Vacant/Improved', 'Sale 2 Book', 'Sale 2 Date',
#        'Sale 2 Document Type', 'Sale 2 Page', 'Sale 2 Price',
#        'Sale 2 Vacant/Improved', 'Subdivision Name', 'Taxable Value',
#        'Total Taxes', 'Tax Roll Year', 'Total Assessed Value',
#        'Property Use Code', 'Property Use Description', 'Year Built',
#        'Grantor, Sale 1', 'Grantor, Sale 2', 'Phone Number', 'Phone Contact',
#        'In Opportunity Zone (Y/N)', 'Opportunity Zone Description'],
#       dtype='object')

# %%
brevard_df.dtypes
# Out:
# Ag Value                          int64
# Total Bathrooms                 float64
# Bedrooms                        float64
# Total Building Area             float64
# Lot Depth (ft)                  float64
# Effective Year Built            float64
# Total Exempt Value                int64
# Fireplace Flag                   object
# Fireplace Count                 float64
# Bathroom Fixtures               float64
# Lot Frontage (ft)               float64
# Garage Flag                      object
# Garage Size (sf)                float64
# Garage Type                      object
# Total Heated (Living) Area      float64
# Improvement 1 Code              float64
# Improvement 1 Description        object
# Improvement 1 Units             float64
# Improvement 2 Code              float64
# Improvement 2 Description       float64
# Improvement 2 Units             float64
# Improvement 3 Code              float64
# Improvement 3 Description       float64
# Improvement 3 Units             float64
# Total Improved Value              int64
# Just Land Value                   int64
# Just Value                        int64
# Lot Size (acres)                float64
# Lot Size (sf)                     int64
# Land Value                        int64
#                                  ...
# Property Address                 object
# Property City                    object
# Property State                   object
# Property Zip Code                object
# Sale 1 Book                     float64
# Sale 1 Date                      object
# Sale 1 Document Type             object
# Sale 1 Page                     float64
# Sale 1 Price                    float64
# Sale 1 Vacant/Improved           object
# Sale 2 Book                     float64
# Sale 2 Date                      object
# Sale 2 Document Type             object
# Sale 2 Page                     float64
# Sale 2 Price                    float64
# Sale 2 Vacant/Improved           object
# Subdivision Name                 object
# Taxable Value                     int64
# Total Taxes                     float64
# Tax Roll Year                   float64
# Total Assessed Value              int64
# Property Use Code                 int64
# Property Use Description         object
# Year Built                      float64
# Grantor, Sale 1                  object
# Grantor, Sale 2                  object
# Phone Number                     object
# Phone Contact                    object
# In Opportunity Zone (Y/N)        object
# Opportunity Zone Description     object
# Length: 70, dtype: object

# %%
sliced_brevard_df = brevard_df[["Owner Name 1","Owner Name 2","Property Address","Property City","Property State","Property Zip Code"]]
# sliced_brevard_df["Latitude"] = ""
# sliced_brevard_df["Longitude"] = ""
sliced_brevard_df.head(-1)
# Out:
#                                            Owner Name 1  \
# 0                                   NESBITT, DAVID A JR
# 1                                     BARNES, KENNETH G
# 2                                        JONES, KARYN M
# 3                                        WELK, DONALD F
# 4                                        WYATT, MARIE W
# 5                                           WREN, LARRY
# 6                                       GROSSMAN, CINDY
# 7                                   PINDZIAK, CHARLES W
# 8                                         KARRAS, PETER
# 9                      COMERICA BANK & TRUST NA TRUSTEE
# 10                                      CLARK, STEVEN D
# 11                                   CHAFFIOT, ROBERT R
# 12                                      BARNETT, JOHN T
# 13                                     PAYNE, KENNETH R
# 14                                       MCCAIN, RAMONA
# 15                                   TOBKES, VELMALEE B
# 16                              THOMAS-BECK, KATHLEEN M
# 17                             MANGROVE ENTERPRISES LLC
# 18                                         PATEL, KEVAT
# 19                                      LAMOTHE, YVES C
# 20                                  RITTER, ERIC THOMAS
# 21                                       SHAH, RASKIN B
# 22                                         SHARMA, AMIT
# 23                                  CHEN, MICHAEL WAYNE
# 24                                       SHAH, SUMMIT M
# 25    ROCKNE J PULCINI & JOYCE C PULCINI REVOCABLE T...
# 26                               HAND, RICHARD JAMES,JR
# 27                                         FARID, MAGED
# 28                                      SCHRUMPF, TERRY
# 29                                       QUADRI, SYED Z
# ...                                                 ...
# 2060                                  COFFEY, KENDALL B
# 2061                                  SIKES, JAMES,JR W
# 2062                                HUSSEIN, MOHAMAD  A
# 2063                                    RTG PROTECH INC
# 2064                                   BABIC, SLAVOLJUB
# 2065                        WISEMAN, HARRY A B TRUSTEES
# 2066                                     ZERVIGON, RUDY
# 2067  DIANA M CRONIN QUALIFIED PERSONAL RESIDENCE TRUST
# 2068                                       DUNCAN, JOHN
# 2069                                DIAMOND, PERRY A JR
# 2070                                TAYLOR, HENRY F III
# 2071                                      DEHUFF, CELIA
# 2072                                       MIR, ROLANDO
# 2073                                 ABEND, ROBERT JAY
# 2074                               GUSTAFSON, RAYMOND P
# 2075                                     MAGAL, CHARLES
# 2076          KATHLEEN M SCHAEFFER 1997 REVOCABLE TRUST
# 2077                      9329 HIGHWAY A1A HOLDINGS LLC
# 2078                               BOZUNG, ROBERT JAMES
# 2079                                       ESPY, BOWERS
# 2080                                    FONSECA, MIGUEL
# 2081                                       HILL, CARL T
# 2082                            MARTINO, ROBERT VINCENT
# 2083                                   HAMILTON, KENT D
# 2084                               GRAHAM MICHAEL MYLES
# 2085                                    HONCHARIK TED E
# 2086                               SLAVIK RICHARD COREY
# 2087                                  BAYER PAUL EUGENE
# 2088                                    KOCOL DEBORAH G
# 2089                                    CALKINS JAMES H
#
#                                            Owner Name 2  \
# 0                                     NESBITT, DENISE M
# 1                                    BARNES, PATRICIA A
# 2                                            JONES, RAY
# 3                                    WELK, JACQUELINE R
# 4                                                   NaN
# 5                                                   NaN
# 6                               GOLDMAN, MITCHELL SCOTT
# 7                               PINDZIAK, HELEN CHAPMAN
# 8                                                   NaN
# 9                                                   NaN
# 10                                      CLARK, SHARON E
# 11                                  CHAFFIOT, ROBEANA G
# 12                                    BARNETT, PENNIE A
# 13                                                  NaN
# 14                                 MCCAIN, STEPHEN FAYE
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                       PATEL, ARCHITA
# 19                                      LAMOTHE, JAEL P
# 20                               RITTER, JENNIFER ROCCO
# 21                                         SHAH, NEHA R
# 22                                      GORTHI, KALPANA
# 23                                       SLOAN, SALLY J
# 24                                         SHAH, MARSHA
# 25                                                  NaN
# 26                                    HAND, TERESA JEAN
# 27                                    GADALLAH, SHIREEN
# 28                                      SCHRUMPF, TANYA
# 29                                     QUADRI, ARSHIA F
# ...                                                 ...
# 2060                                     COFFEY, JONI A
# 2061                                                NaN
# 2062                                HUSSEIN, NATALIE  A
# 2063                                                NaN
# 2064                                      BABIC, CHRYSA
# 2065                           WISEMAN, REVA S TRUSTEES
# 2066                               ZERVIGON, ALISA HOPE
# 2067  JAMES P CRONIN QUALIFIED PERSONAL RESIDENCE TRUST
# 2068                                   DUNCAN, JENNIFER
# 2069                                    DIAMOND, BLANCA
# 2070                                   TAYLOR, SANDRA J
# 2071                                       DORNE, PETER
# 2072                                        MIR, ESTHER
# 2073                                      ABEND, SUN I
# 2074                                                NaN
# 2075                                  STAMATACOS, HELEN
# 2076                                                NaN
# 2077                                                NaN
# 2078                                  BOZUNG, ELIZABETH
# 2079                                    ESPY, ANN THOKE
# 2080                                   FONSECA, KRISTIN
# 2081                                      HILL, VICKI L
# 2082                                MARTINO, LORI ELLEN
# 2083                        HAMILTON, ANN L CO-TRUSTEES
# 2084                                                NaN
# 2085                                                NaN
# 2086                                                NaN
# 2087                                                NaN
# 2088                                                NaN
# 2089                                                NaN
#
#                  Property Address    Property City Property State  \
# 0                 7727 KIAWAH WAY  MELBOURNE BEACH             FL
# 1               3980 PINETOP BLVD       TITUSVILLE             FL
# 2              1145 SAND PINE CIR       TITUSVILLE             FL
# 3                   3485 RANEY RD       TITUSVILLE             FL
# 4           3415 S WASHINGTON AVE       TITUSVILLE             FL
# 5           3435 S WASHINGTON AVE       TITUSVILLE             FL
# 6             4002 TRADEWINDS TRL   MERRITT ISLAND             FL
# 7              112 E CENTRAL BLVD   CAPE CANAVERAL             FL
# 8             4052 TRADEWINDS TRL   MERRITT ISLAND             FL
# 9                100 BROOKHILL DR            COCOA             FL
# 10         1848 TIMBERS WEST BLVD        ROCKLEDGE             FL
# 11               8 RIVER RIDGE DR        ROCKLEDGE             FL
# 12                   924 DERBY LN        ROCKLEDGE             FL
# 13                 51 BAYSHORE CT        ROCKLEDGE             FL
# 14          2195 S COURTENAY PKWY   MERRITT ISLAND             FL
# 15                 40 BAYSHORE CT        ROCKLEDGE             FL
# 16              2197 ROCKLEDGE DR        ROCKLEDGE             FL
# 17              1875 ROCKLEDGE DR        ROCKLEDGE             FL
# 18              3012 BELLWIND CIR        ROCKLEDGE             FL
# 19              2992 BELLWIND CIR        ROCKLEDGE             FL
# 20              3032 BELLWIND CIR        ROCKLEDGE             FL
# 21              2962 BELLWIND CIR        ROCKLEDGE             FL
# 22              2942 BELLWIND CIR        ROCKLEDGE             FL
# 23              2912 BELLWIND CIR        ROCKLEDGE             FL
# 24              2902 BELLWIND CIR        ROCKLEDGE             FL
# 25              2892 BELLWIND CIR        ROCKLEDGE             FL
# 26              3093 BELLWIND CIR        ROCKLEDGE             FL
# 27              3083 BELLWIND CIR        ROCKLEDGE             FL
# 28               4664 TEA TREE CT        ROCKLEDGE             FL
# 29              3073 BELLWIND CIR        ROCKLEDGE             FL
# ...                           ...              ...            ...
# 2060           8905 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2061           8935 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2062           8955 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2063  8515 S HIGHWAY A1A # DUPLEX  MELBOURNE BEACH             FL
# 2064            200 STRAWBERRI LN  MELBOURNE BEACH             FL
# 2065           8965 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2066           8735 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2067           8985 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2068            150 RIVER OAKS RD  MELBOURNE BEACH             FL
# 2069           9155 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2070           9235 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2071           9025 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2072           9265 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2073           8790 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2074             125 RUE DE NANCY  MELBOURNE BEACH             FL
# 2075           9010 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2076           9255 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2077           9329 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2078           9335 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2079           9315 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2080           9333 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2081           9515 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2082           9445 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2083           9349 S HIGHWAY A1A  MELBOURNE BEACH             FL
# 2084          5575 S US HIGHWAY 1   GRANT VALKARIA             FL
# 2085          2289 S ATLANTIC AVE      COCOA BEACH             FL
# 2086            2883 BELLWIND CIR        ROCKLEDGE             FL
# 2087           153 HIDDEN COVE DR  MELBOURNE BEACH             FL
# 2088          8060 S TROPICAL TRL   MERRITT ISLAND             FL
# 2089           3725 S HIGHWAY A1A  MELBOURNE BEACH             FL
#
#      Property Zip Code
# 0           32951-3989
# 1           32796-3614
# 2           32796-3635
# 3           32780-3504
# 4           32780-5664
# 5           32780-5664
# 6           32953-8077
# 7           32920-2606
# 8           32953-8077
# 9           32926-8736
# 10          32955-3425
# 11          32955-2947
# 12          32955-6107
# 13          32955-4934
# 14          32952-4013
# 15          32955-4934
# 16          32955-5401
# 17          32955-4909
# 18          32955-5171
# 19          32955-5141
# 20          32955-5171
# 21          32955-5141
# 22          32955-5141
# 23          32955-5141
# 24          32955-5141
# 25          32955-5194
# 26          32955-5172
# 27          32955-5172
# 28          32955-5114
# 29          32955-5172
# ...                ...
# 2060        32951-4012
# 2061        32951-4012
# 2062        32951-4012
# 2063        32951-4025
# 2064        32951-4022
# 2065        32951-4012
# 2066        32951-4008
# 2067        32951-4012
# 2068        32951-4019
# 2069        32951-4016
# 2070        32951-4102
# 2071        32951-4014
# 2072        32951-4102
# 2073        32951-4007
# 2074        32951-4021
# 2075        32951-4000
# 2076        32951-4102
# 2077        32951-4104
# 2078        32951-4104
# 2079        32951-4104
# 2080        32951-4104
# 2081        32951-4108
# 2082        32951-4106
# 2083        32951-4104
# 2084        32949-2012
# 2085        32931-2236
# 2086        32955-5195
# 2087        32951-3346
# 2088        32952-6710
# 2089        32951-3110
#
# [2090 rows x 6 columns]

# %% [markdown]
# ### Pull in Latitude & Longitude for all Addresses

# %%
sliced_brevard_df.keys()
# Out:
# Index(['Owner Name 1', 'Owner Name 2', 'Property Address', 'Property City',
#        'Property State', 'Property Zip Code'],
#       dtype='object')

# %%
street_addy = sliced_brevard_df[["Property Address"]]
street_addy.iloc[0]
# Out:
# Property Address    7727 KIAWAH WAY
# Name: 0, dtype: object

# %%
sliced_brevard_df['Property City'].value_counts()
# Out:
# MERRITT ISLAND          472
# MELBOURNE BEACH         418
# INDIALANTIC             241
# MELBOURNE               223
# COCOA BEACH             172
# ROCKLEDGE               170
# SATELLITE BEACH         157
# INDIAN HARBOUR BEACH    148
# COCOA                    23
# MALABAR                  16
# CAPE CANAVERAL           12
# SEBASTIAN                 9
# GRANT VALKARIA            9
# PALM BAY                  8
# TITUSVILLE                8
# Name: Property City, dtype: int64

# %%
import json
import requests
from requests.auth import HTTPBasicAuth

coordinal_api = "https://api.mapbox.com/geocoding/v5/mapbox.places/1875%20Rockledge%20Dr%20Rockledge%20FL%2032955.json?access_token=pk.eyJ1IjoiY3J5cHRvbWFydGluZ2FsZWxvdmVyIiwiYSI6ImNrcXptZjdxZTFqYmEydnBhOTBiNnBucDMifQ.i74IyaGAx6rj5oHmlo41Lw"
# response_coordinal_api = requests.get(coordinal_api,data=json,auth=('cryptomartingalelover', '20mapboX21'))

response_coordinal_api = requests.get(coordinal_api)

# Format BTC data as JSON
coordinal_json = response_coordinal_api.json()

# Use json.dumps to format data
print(json.dumps(coordinal_json, indent=8))
# Out:
# {
#         "type": "FeatureCollection",
#         "query": [
#                 "1875",
#                 "rockledge",
#                 "dr",
#                 "rockledge",
#                 "fl",
#                 "32955"
#         ],
#         "features": [
#                 {
#                         "id": "address.4636370742055024",
#                         "type": "Feature",
#                         "place_type": [
#                                 "address"
#                         ],
#                         "relevance": 1,
#                         "properties": {
#                                 "accuracy": "rooftop"
#                         },
#                         "text": "Rockledge Drive",
#                         "place_name": "1875 Rockledge Drive, Rockledge, Florida 32955, United States",
#                         "center": [
#                                 -80.701778,
#                                 28.301224
#                         ],
#                         "geometry": {
#                                 "type": "Point",
#                                 "coordinates": [
#                                         -80.701778,
#                                         28.301224
#                                 ]
#                         },
#                         "address": "1875",
#                         "context": [
#                                 {
#                                         "id": "postcode.18914397791000900",
#                                         "text": "32955"
#                                 },
#                                 {
#                                         "id": "place.13431499929130480",
#                                         "wikidata": "Q1979566",
#                                         "text": "Rockledge"
#                                 },
#                                 {
#                                         "id": "district.14510513454517340",
#                                         "wikidata": "Q488517",
#                                         "text": "Brevard County"
#                                 },
#                                 {
#                                         "id": "region.7862008843235010",
#                                         "wikidata": "Q812",
#                                         "short_code": "US-FL",
#                                         "text": "Florida"
#                                 },
#                                 {
#                                         "id": "country.19678805456372290",
#                                         "wikidata": "Q30",
#                                         "short_code": "us",
#                                         "text": "United States"
#                                 }
#                         ]
#                 },
#                 {
#                         "id": "address.582585070487590",
#                         "type": "Feature",
#                         "place_type": [
#                                 "address"
#                         ],
#                         "relevance": 0.814815,
#                         "properties": {
#                                 "accuracy": "street"
#                         },
#                         "text": "Rockledge Drive",
#                         "place_name": "Rockledge Drive, Rockledge, Florida 32955, United States",
#                         "center": [
#                                 -80.7214050585714,
#                                 28.34506045
#                         ],
#                         "geometry": {
#                                 "type": "Point",
#                                 "coordinates": [
#                                         -80.7214050585714,
#                                         28.34506045
#                                 ]
#                         },
#                         "context": [
#                                 {
#                                         "id": "neighborhood.288691",
#                                         "text": "Downtown Cocoa"
#                                 },
#                                 {
#                                         "id": "postcode.18914397791000900",
#                                         "text": "32955"
#                                 },
#                                 {
#                                         "id": "place.13431499929130480",
#                                         "wikidata": "Q1979566",
#                                         "text": "Rockledge"
#                                 },
#                                 {
#                                         "id": "district.14510513454517340",
#                                         "wikidata": "Q488517",
#                                         "text": "Brevard County"
#                                 },
#                                 {
#                                         "id": "region.7862008843235010",
#                                         "wikidata": "Q812",
#                                         "short_code": "US-FL",
#                                         "text": "Florida"
#                                 },
#                                 {
#                                         "id": "country.19678805456372290",
#                                         "wikidata": "Q30",
#                                         "short_code": "us",
#                                         "text": "United States"
#                                 }
#                         ]
#                 },
#                 {
#                         "id": "address.1694764908171050",
#                         "type": "Feature",
#                         "place_type": [
#                                 "address"
#                         ],
#                         "relevance": 0.703704,
#                         "properties": {
#                                 "accuracy": "street"
#                         },
#                         "text": "Rockledge Blvd",
#                         "place_name": "Rockledge Blvd, Rockledge, Florida 32955, United States",
#                         "center": [
#                                 -80.7276059,
#                                 28.3490656
#                         ],
#                         "geometry": {
#                                 "type": "Point",
#                                 "coordinates": [
#                                         -80.7276059,
#                                         28.3490656
#                                 ]
#                         },
#                         "context": [
#                                 {
#                                         "id": "neighborhood.288691",
#                                         "text": "Downtown Cocoa"
#                                 },
#                                 {
#                                         "id": "postcode.18914397791000900",
#                                         "text": "32955"
#                                 },
#                                 {
#                                         "id": "place.13431499929130480",
#                                         "wikidata": "Q1979566",
#                                         "text": "Rockledge"
#                                 },
#                                 {
#                                         "id": "district.14510513454517340",
#                                         "wikidata": "Q488517",
#                                         "text": "Brevard County"
#                                 },
#                                 {
#                                         "id": "region.7862008843235010",
#                                         "wikidata": "Q812",
#                                         "short_code": "US-FL",
#                                         "text": "Florida"
#                                 },
#                                 {
#                                         "id": "country.19678805456372290",
#                                         "wikidata": "Q30",
#                                         "short_code": "us",
#                                         "text": "United States"
#                                 }
#                         ]
#                 },
#                 {
#                         "id": "address.7066811143617214",
#                         "type": "Feature",
#                         "place_type": [
#                                 "address"
#                         ],
#                         "relevance": 0.654684,
#                         "properties": {
#                                 "accuracy": "interpolated"
#                         },
#                         "text": "Rockledge Road",
#                         "place_name": "1875 Rockledge Road, Rockledge, Georgia 30454, United States",
#                         "center": [
#                                 -82.70154,
#                                 32.463385
#                         ],
#                         "geometry": {
#                                 "type": "Point",
#                                 "coordinates": [
#                                         -82.70154,
#                                         32.463385
#                                 ],
#                                 "interpolated": true,
#                                 "omitted": true
#                         },
#                         "address": "1875",
#                         "context": [
#                                 {
#                                         "id": "postcode.7626990294642710",
#                                         "text": "30454"
#                                 },
#                                 {
#                                         "id": "place.16594172081130480",
#                                         "wikidata": "Q22058913",
#                                         "text": "Rockledge"
#                                 },
#                                 {
#                                         "id": "district.5966318850411100",
#                                         "wikidata": "Q491556",
#                                         "text": "Laurens County"
#                                 },
#                                 {
#                                         "id": "region.10288430666212700",
#                                         "wikidata": "Q1428",
#                                         "short_code": "US-GA",
#                                         "text": "Georgia"
#                                 },
#                                 {
#                                         "id": "country.19678805456372290",
#                                         "wikidata": "Q30",
#                                         "short_code": "us",
#                                         "text": "United States"
#                                 }
#                         ]
#                 },
#                 {
#                         "id": "postcode.18914397791000900",
#                         "type": "Feature",
#                         "place_type": [
#                                 "postcode"
#                         ],
#                         "relevance": 0.638889,
#                         "properties": {},
#                         "text": "32955",
#                         "place_name": "Rockledge, Florida 32955, United States",
#                         "bbox": [
#                                 -80.7747297591129,
#                                 28.2194483211377,
#                                 -80.6634741298014,
#                                 28.3494858986414
#                         ],
#                         "center": [
#                                 -80.74,
#                                 28.34
#                         ],
#                         "geometry": {
#                                 "type": "Point",
#                                 "coordinates": [
#                                         -80.74,
#                                         28.34
#                                 ]
#                         },
#                         "context": [
#                                 {
#                                         "id": "place.13431499929130480",
#                                         "wikidata": "Q1979566",
#                                         "text": "Rockledge"
#                                 },
#                                 {
#                                         "id": "district.14510513454517340",
#                                         "wikidata": "Q488517",
#                                         "text": "Brevard County"
#                                 },
#                                 {
#                                         "id": "region.7862008843235010",
#                                         "wikidata": "Q812",
#                                         "short_code": "US-FL",
#                                         "text": "Florida"
#                                 },
#                                 {
#                                         "id": "country.19678805456372290",
#                                         "wikidata": "Q30",
#                                         "short_code": "us",
#                                         "text": "United States"
#                                 }
#                         ]
#                 }
#         ],
#         "attribution": "NOTICE: \u00a9 2021 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare."
# }

# %%
coordinal_json['features'][0]['geometry']['coordinates']
# Out:
# [-80.701778, 28.301224]

# %%
lat = coordinal_json['features'][0]['geometry']['coordinates'][0]
lat
# Out:
# -80.701778

# %%
lon = coordinal_json['features'][0]['geometry']['coordinates'][1]
lon
# Out:
# 28.301224

# %%
'''
I want to:
1. Call variable to concatenate the addresses in sliced_brevard_df to have one full address in URL-encoded UTF-8 string.
2. Plug the encoded address into the api url to pull the json.
3. Exract the coordinates from each address. 
4. Assign variables lat and lon to the respective parts of the coordinates. 
5. Deliver values for lat & lon variables into separate new columns in the df. 
6. Use the lat & lon to plot the data on a mapbox map.

'''
address_with_url_utf8 = pd.read_csv(
    Path(r"750k_and_up_url_utf8.csv"),
)
address_with_url_utf8.drop(columns=['Property Address', 'Unnamed: 1', 'Property City', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Property State', 'Unnamed: 9', 'Unnamed: 10', 'Property Zip Code'], inplace=True)
address_with_url_utf8["API_Address"] = ""
address_with_url_utf8["Latitude"] = ""
address_with_url_utf8["Longitude"] = ""
address_with_url_utf8.head()
# Out:
#                                       Full URL UTF-8 API_Address Latitude  \
# 0  7727%20KIAWAH%20WAY%20MELBOURNE%20BEACH%20FL%2...
# 1  3980%20PINETOP%20BLVD%20TITUSVILLE%20FL%203279...
# 2  1145%20SAND%20PINE%20CIR%20TITUSVILLE%20FL%203...
# 3   3485%20RANEY%20RD%20TITUSVILLE%20FL%2032780-3504
# 4  3415%20S%20WASHINGTON%20AVE%20TITUSVILLE%20FL%...
#
#   Longitude
# 0
# 1
# 2
# 3
# 4

# %%
address_with_url_utf8.shape
# Out:
# (2091, 1)

# %%
address_with_url_utf8.keys()

utf8 = address_with_url_utf8[:]['Full URL UTF-8']
# utf8.head()
api_address = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{utf8}.json?access_token=pk.eyJ1IjoiY3J5cHRvbWFydGluZ2FsZWxvdmVyIiwiYSI6ImNrcXptZjdxZTFqYmEydnBhOTBiNnBucDMifQ.i74IyaGAx6rj5oHmlo41Lw"
api_address
# Out:
# 'https://api.mapbox.com/geocoding/v5/mapbox.places/0       7727%20KIAWAH%20WAY%20MELBOURNE%20BEACH%20FL%2...\n1       3980%20PINETOP%20BLVD%20TITUSVILLE%20FL%203279...\n2       1145%20SAND%20PINE%20CIR%20TITUSVILLE%20FL%203...\n3        3485%20RANEY%20RD%20TITUSVILLE%20FL%2032780-3504\n4       3415%20S%20WASHINGTON%20AVE%20TITUSVILLE%20FL%...\n5       3435%20S%20WASHINGTON%20AVE%20TITUSVILLE%20FL%...\n6       4002%20TRADEWINDS%20TRL%20MERRITT%20ISLAND%20F...\n7       112%20E%20CENTRAL%20BLVD%20CAPE%20CANAVERAL%20...\n8       4052%20TRADEWINDS%20TRL%20MERRITT%20ISLAND%20F...\n9          100%20BROOKHILL%20DR%20COCOA%20FL%2032926-8736\n10      1848%20TIMBERS%20WEST%20BLVD%20ROCKLEDGE%20FL%...\n11      8%20RIVER%20RIDGE%20DR%20ROCKLEDGE%20FL%203295...\n12         924%20DERBY%20LN%20ROCKLEDGE%20FL%2032955-6107\n13       51%20BAYSHORE%20CT%20ROCKLEDGE%20FL%2032955-4934\n14      2195%20S%20COURTENAY%20PKWY%20MERRITT%20ISLAND...\n15       40%20BAYSHORE%20CT%20ROCKLEDGE%20FL%2032955-4934\n16      2197%20ROCKLEDGE%20DR%20ROCKLEDGE%20FL%2032955...\n17      1875%20ROCKLEDGE%20DR%20ROCKLEDGE%20FL%2032955...\n18      3012%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n19      2992%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n20      3032%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n21      2962%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n22      2942%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n23      2912%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n24      2902%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n25      2892%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n26      3093%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n27      3083%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n28      4664%20TEA%20TREE%20CT%20ROCKLEDGE%20FL%203295...\n29      3073%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n                              ...                        \n2061    8935%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2062    8955%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2063    8515%20S%20HIGHWAY%20A1A%20%23%20DUPLEX%20MELB...\n2064    200%20STRAWBERRI%20LN%20MELBOURNE%20BEACH%20FL...\n2065    8965%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2066    8735%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2067    8985%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2068    150%20RIVER%20OAKS%20RD%20MELBOURNE%20BEACH%20...\n2069    9155%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2070    9235%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2071    9025%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2072    9265%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2073    8790%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2074    125%20RUE%20DE%20NANCY%20MELBOURNE%20BEACH%20F...\n2075    9010%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2076    9255%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2077    9329%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2078    9335%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2079    9315%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2080    9333%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2081    9515%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2082    9445%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2083    9349%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2084    5575%20S%20US%20HIGHWAY%201%20GRANT%20VALKARIA...\n2085    2289%20S%20ATLANTIC%20AVE%20COCOA%20BEACH%20FL...\n2086    2883%20BELLWIND%20CIR%20ROCKLEDGE%20FL%2032955...\n2087    153%20HIDDEN%20COVE%20DR%20MELBOURNE%20BEACH%2...\n2088    8060%20S%20TROPICAL%20TRL%20MERRITT%20ISLAND%2...\n2089    3725%20S%20HIGHWAY%20A1A%20MELBOURNE%20BEACH%2...\n2090    2320%20S%20RIVER%20RD%20MELBOURNE%20BEACH%20FL...\nName: Full URL UTF-8, Length: 2091, dtype: object.json?access_token=pk.eyJ1IjoiY3J5cHRvbWFydGluZ2FsZWxvdmVyIiwiYSI6ImNrcXptZjdxZTFqYmEydnBhOTBiNnBucDMifQ.i74IyaGAx6rj5oHmlo41Lw'

# %%
address_with_url_utf8["API_Address"] = api_address
address_with_url_utf8.head()
# Out:
#                                       Full URL UTF-8  \
# 0  7727%20KIAWAH%20WAY%20MELBOURNE%20BEACH%20FL%2...
# 1  3980%20PINETOP%20BLVD%20TITUSVILLE%20FL%203279...
# 2  1145%20SAND%20PINE%20CIR%20TITUSVILLE%20FL%203...
# 3   3485%20RANEY%20RD%20TITUSVILLE%20FL%2032780-3504
# 4  3415%20S%20WASHINGTON%20AVE%20TITUSVILLE%20FL%...
#
#                                          API_Address Latitude Longitude
# 0  https://api.mapbox.com/geocoding/v5/mapbox.pla...
# 1  https://api.mapbox.com/geocoding/v5/mapbox.pla...
# 2  https://api.mapbox.com/geocoding/v5/mapbox.pla...
# 3  https://api.mapbox.com/geocoding/v5/mapbox.pla...
# 4  https://api.mapbox.com/geocoding/v5/mapbox.pla...

# %%
address_with_url_utf8.keys()
# Out:
# Index(['Full URL UTF-8', 'API_Address', 'Latitude', 'Longitude'], dtype='object')

# %%
def get_coordinates():
    for item in address_with_url_utf8['API_Address']:
        item_response = requests.get(api_address)
        item_json = item_response.json()
        lat = item_json['features'][0]['geometry']['coordinates'][0]
        lon = item_json['features'][0]['geometry']['coordinates'][1]
        address_with_url_utf8["Latitude"] = lat
        address_with_url_utf8["Longitude"] = lon
    return

get_coordinates(item)

# %%
address_with_url_utf8.head()
# Out:
#                                       Full URL UTF-8  \
# 0  7727%20KIAWAH%20WAY%20MELBOURNE%20BEACH%20FL%2...
# 1  3980%20PINETOP%20BLVD%20TITUSVILLE%20FL%203279...
# 2  1145%20SAND%20PINE%20CIR%20TITUSVILLE%20FL%203...
# 3   3485%20RANEY%20RD%20TITUSVILLE%20FL%2032780-3504
# 4  3415%20S%20WASHINGTON%20AVE%20TITUSVILLE%20FL%...
#
#                                          API_Address   Latitude  Longitude
# 0  https://api.mapbox.com/geocoding/v5/mapbox.pla... -80.701778  28.301224
# 1  https://api.mapbox.com/geocoding/v5/mapbox.pla... -80.701778  28.301224
# 2  https://api.mapbox.com/geocoding/v5/mapbox.pla... -80.701778  28.301224
# 3  https://api.mapbox.com/geocoding/v5/mapbox.pla... -80.701778  28.301224
# 4  https://api.mapbox.com/geocoding/v5/mapbox.pla... -80.701778  28.301224
